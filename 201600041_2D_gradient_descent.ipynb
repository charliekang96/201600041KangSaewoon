# %% [markdown]
# <a href="https://colab.research.google.com/github/charliekang96/201600041KangSaewoon/blob/main/201600041_2D_gradient_descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D

def f(a,b):
	return (2/3)* a**2 + (1/3)* b**4 +2* np.sin(a*b)

def grad_f(a,b): 
  h=1e-5
  return [(f(a+h,b) - f(a-h,b))/(2*h),(f(a,b+h) - f(a,b-h))/(2*h)]


def gradient_descent(theta0, iters, alpha):
	history = [theta0]
	theta = theta0    
	for i in range(iters):
		gradient = grad_f(theta[0],theta[1])
		theta = [a - alpha*b for a,b in zip(theta, gradient)]
		history.append(theta)
	return history

history = gradient_descent(theta0 = [-2, -2], iters =60, alpha = 0.1)


fig = plt.figure(figsize=(20, 15))
ax = fig.gca(projection='3d')
a = np.arange(-2, 2, 0.25)
b = np.arange(-2, 2, 0.25)
a, b = np.meshgrid(a, b)
c = f(a,b)
surf = ax.plot_surface(a, b, c, rstride=1, cstride=1, alpha=0.4, 
		 linewidth=0, antialiased=False, cmap='rainbow')


a = np.array([x[0] for x in history])
b = np.array([x[1] for x in history])
c =  f(a,b)
ax.scatter(a, b, c, color="r"); 

print(c)


plt.xlabel('Feature A')
plt.ylabel('Feature B')

plt.show()
# Out:
# [ 6.48639501e+00  4.70735149e+00  4.60855124e+00  4.56052723e+00
#   4.49775315e+00  4.36936372e+00  4.08886099e+00  3.51658223e+00
#   2.58919409e+00  1.57947156e+00  8.53105234e-01  4.41996674e-01
#   2.25275975e-01  1.11357642e-01  5.02125517e-02  1.58720576e-02
#  -5.23551382e-03 -2.03697944e-02 -3.35791088e-02 -4.72989394e-02
#  -6.31851395e-02 -8.25460152e-02 -1.06552141e-01 -1.36306560e-01
#  -1.72805462e-01 -2.16791290e-01 -2.68492500e-01 -3.27264512e-01
#  -3.91209655e-01 -4.56964422e-01 -5.19948020e-01 -5.75308828e-01
#  -6.19401783e-01 -6.51023964e-01 -6.71520809e-01 -6.83707921e-01
#  -6.90508476e-01 -6.94157929e-01 -6.96079299e-01 -6.97084391e-01
#  -6.97610056e-01 -6.97885497e-01 -6.98030117e-01 -6.98106163e-01
#  -6.98146190e-01 -6.98167269e-01 -6.98178372e-01 -6.98184221e-01
#  -6.98187303e-01 -6.98188926e-01 -6.98189782e-01 -6.98190232e-01
#  -6.98190469e-01 -6.98190594e-01 -6.98190660e-01 -6.98190695e-01
# ...
